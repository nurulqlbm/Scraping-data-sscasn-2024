# %%
# https://api-sscasn.bkn.go.id/2024/portal/spf?kode_ref_pend=5101087&pengadaan_kd=2&offset=0

# %%
import requests
import csv
import time

headers = {
        'Accept': 'application/json, text/plain, */*',
        'Accept-Encoding': 'gzip, deflate, br, zstd',
        'Accept-Language': 'id-ID,id;q=0.9,en-US;q=0.8,en;q=0.7',
        'Cache-Control': 'no-cache',
        'Connection': 'keep-alive',
        'Host': 'api-sscasn.bkn.go.id',
        'Origin': 'https://sscasn.bkn.go.id',
        'Pragma': 'no-cache',
        'Referer': 'https://sscasn.bkn.go.id/',
        'Sec-Fetch-Dest': 'empty',
        'Sec-Fetch-Mode': 'cors',
        'Sec-Fetch-Site': 'same-site',
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/136.0.0.0 Safari/537.36',
        'sec-ch-ua': '"Chromium";v="136", "Google Chrome";v="136", "Not.A/Brand";v="99"',
        'sec-ch-ua-mobile': '?0',
        'sec-ch-ua-platform': '"Windows"'
}

# %%
total_data = 9541
limit = 10
kode_ref_pend = '5101087'
pengadaan_kd = '2'

all_data = []

session = requests.Session()

for offset in range(0, total_data, limit):
    url = f"https://api-sscasn.bkn.go.id/2024/portal/spf?kode_ref_pend={kode_ref_pend}&pengadaan_kd={pengadaan_kd}&offset={offset}"
    print(f"Fetching data offset {offset} ...")

    try:
        response = session.get(url, headers=headers)
        data = response.json()

        for row in data['data']['data']:
            all_data.append([
                row.get('ins_nm', ''),
                row.get('jp_nama', ''),
                row.get('formasi_nm', ''),
                row.get('jabatan_nm', ''),
                row.get('lokasi_nm', ''),
                row.get('jumlah_formasi', ''),
                row.get('gaji_min', ''),
                row.get('gaji_max', ''),
                row.get('jumlah_ms', '')
            ])

    except Exception as e:
        print(f"Gagal mengambil data di offset {offset}: {e}")

    time.sleep(0.3)

# Simpan ke CSV
with open("formasi_sscasn_2024.csv", "w", newline="", encoding="utf-8") as f:
    writer = csv.writer(f)
    writer.writerow(["Instansi", "Jabatan", "Lokasi", "Pendidikan", "Jumlah Formasi"])
    writer.writerows(all_data)

print(f"\n✅ Selesai! Total data terkumpul: {len(all_data)}")
# Out:
# Fetching data offset 0 ...
# Fetching data offset 10 ...
# Fetching data offset 20 ...
# Fetching data offset 30 ...
# Fetching data offset 40 ...
# Fetching data offset 50 ...
# Fetching data offset 60 ...
# Fetching data offset 70 ...
# Fetching data offset 80 ...
# Fetching data offset 90 ...
# Fetching data offset 100 ...
# Fetching data offset 110 ...
# Fetching data offset 120 ...
# Fetching data offset 130 ...
# Fetching data offset 140 ...
# Fetching data offset 150 ...
# Fetching data offset 160 ...
# Fetching data offset 170 ...
# Fetching data offset 180 ...
# Fetching data offset 190 ...
# Fetching data offset 200 ...
# Fetching data offset 210 ...
# Fetching data offset 220 ...
# Fetching data offset 230 ...
# Fetching data offset 240 ...
# Fetching data offset 250 ...
# Fetching data offset 260 ...
# Fetching data offset 270 ...
# Fetching data offset 280 ...
# Fetching data offset 290 ...
# Fetching data offset 300 ...
# Fetching data offset 310 ...
# Fetching data offset 320 ...
# Fetching data offset 330 ...
# Fetching data offset 340 ...
# Fetching data offset 350 ...
# Fetching data offset 360 ...
# Fetching data offset 370 ...
# Fetching data offset 380 ...
# Fetching data offset 390 ...
# Fetching data offset 400 ...
# Fetching data offset 410 ...
# Fetching data offset 420 ...
# Fetching data offset 430 ...
# Fetching data offset 440 ...
# Fetching data offset 450 ...
# Fetching data offset 460 ...
# Fetching data offset 470 ...
# Fetching data offset 480 ...
# Fetching data offset 490 ...
# Fetching data offset 500 ...
# Fetching data offset 510 ...
# Fetching data offset 520 ...
# Fetching data offset 530 ...
# Fetching data offset 540 ...
# Fetching data offset 550 ...
# Fetching data offset 560 ...
# Fetching data offset 570 ...
# Fetching data offset 580 ...
# Fetching data offset 590 ...
# Fetching data offset 600 ...
# Fetching data offset 610 ...
# Fetching data offset 620 ...
# Fetching data offset 630 ...
# Fetching data offset 640 ...
# Fetching data offset 650 ...
# Fetching data offset 660 ...
# Fetching data offset 670 ...
# Fetching data offset 680 ...
# Fetching data offset 690 ...
# Fetching data offset 700 ...
# Fetching data offset 710 ...
# Fetching data offset 720 ...
# Fetching data offset 730 ...
# Fetching data offset 740 ...
# Fetching data offset 750 ...
# Fetching data offset 760 ...
# Fetching data offset 770 ...
# Fetching data offset 780 ...
# Fetching data offset 790 ...
# Fetching data offset 800 ...
# Fetching data offset 810 ...
# Fetching data offset 820 ...
# Fetching data offset 830 ...
# Fetching data offset 840 ...
# Fetching data offset 850 ...
# Fetching data offset 860 ...
# Fetching data offset 870 ...
# Fetching data offset 880 ...
# Fetching data offset 890 ...
# Fetching data offset 900 ...
# Fetching data offset 910 ...
# Fetching data offset 920 ...
# Fetching data offset 930 ...
# Fetching data offset 940 ...
# Fetching data offset 950 ...
# Fetching data offset 960 ...
# Fetching data offset 970 ...
# Fetching data offset 980 ...
# Fetching data offset 990 ...
# Fetching data offset 1000 ...
# Fetching data offset 1010 ...
# Fetching data offset 1020 ...
# Fetching data offset 1030 ...
# Fetching data offset 1040 ...
# Fetching data offset 1050 ...
# Fetching data offset 1060 ...
# Fetching data offset 1070 ...
# Fetching data offset 1080 ...
# Fetching data offset 1090 ...
# Fetching data offset 1100 ...
# Fetching data offset 1110 ...
# Fetching data offset 1120 ...
# Fetching data offset 1130 ...
# Fetching data offset 1140 ...
# Fetching data offset 1150 ...
# Fetching data offset 1160 ...
# Fetching data offset 1170 ...
# Fetching data offset 1180 ...
# Fetching data offset 1190 ...
# Fetching data offset 1200 ...
# Fetching data offset 1210 ...
# Fetching data offset 1220 ...
# Fetching data offset 1230 ...
# Fetching data offset 1240 ...
# Fetching data offset 1250 ...
# Fetching data offset 1260 ...
# Fetching data offset 1270 ...
# Fetching data offset 1280 ...
# Fetching data offset 1290 ...
# Fetching data offset 1300 ...
# Fetching data offset 1310 ...
# Fetching data offset 1320 ...
# Fetching data offset 1330 ...
# Fetching data offset 1340 ...
# Fetching data offset 1350 ...
# Fetching data offset 1360 ...
# Fetching data offset 1370 ...
# Fetching data offset 1380 ...
# Fetching data offset 1390 ...
# Fetching data offset 1400 ...
# Fetching data offset 1410 ...
# Fetching data offset 1420 ...
# Fetching data offset 1430 ...
# Fetching data offset 1440 ...
# Fetching data offset 1450 ...
# Fetching data offset 1460 ...
# Fetching data offset 1470 ...
# Fetching data offset 1480 ...
# Fetching data offset 1490 ...
# Fetching data offset 1500 ...
# Fetching data offset 1510 ...
# Fetching data offset 1520 ...
# Fetching data offset 1530 ...
# Fetching data offset 1540 ...
# Fetching data offset 1550 ...
# Fetching data offset 1560 ...
# Fetching data offset 1570 ...
# Fetching data offset 1580 ...
# Fetching data offset 1590 ...
# Fetching data offset 1600 ...
# Fetching data offset 1610 ...
# Fetching data offset 1620 ...
# Fetching data offset 1630 ...
# Fetching data offset 1640 ...
# Fetching data offset 1650 ...
# Fetching data offset 1660 ...
# Fetching data offset 1670 ...
# Fetching data offset 1680 ...
# Fetching data offset 1690 ...
# Fetching data offset 1700 ...
# Fetching data offset 1710 ...
# Fetching data offset 1720 ...
# Fetching data offset 1730 ...
# Fetching data offset 1740 ...
# Fetching data offset 1750 ...
# Fetching data offset 1760 ...
# Fetching data offset 1770 ...
# Fetching data offset 1780 ...
# Fetching data offset 1790 ...
# Fetching data offset 1800 ...
# Fetching data offset 1810 ...
# Fetching data offset 1820 ...
# Fetching data offset 1830 ...
# Fetching data offset 1840 ...
# Fetching data offset 1850 ...
# Fetching data offset 1860 ...
# Fetching data offset 1870 ...
# Fetching data offset 1880 ...
# Fetching data offset 1890 ...
# Fetching data offset 1900 ...
# Fetching data offset 1910 ...
# Fetching data offset 1920 ...
# Fetching data offset 1930 ...
# Fetching data offset 1940 ...
# Fetching data offset 1950 ...
# Fetching data offset 1960 ...
# Fetching data offset 1970 ...
# Fetching data offset 1980 ...
# Fetching data offset 1990 ...
# Fetching data offset 2000 ...
# Fetching data offset 2010 ...
# Fetching data offset 2020 ...
# Fetching data offset 2030 ...
# Fetching data offset 2040 ...
# Fetching data offset 2050 ...
# Fetching data offset 2060 ...
# Fetching data offset 2070 ...
# Fetching data offset 2080 ...
# Fetching data offset 2090 ...
# Fetching data offset 2100 ...
# Fetching data offset 2110 ...
# Fetching data offset 2120 ...
# Fetching data offset 2130 ...
# Fetching data offset 2140 ...
# Fetching data offset 2150 ...
# Fetching data offset 2160 ...
# Fetching data offset 2170 ...
# Fetching data offset 2180 ...
# Fetching data offset 2190 ...
# Fetching data offset 2200 ...
# Fetching data offset 2210 ...
# Fetching data offset 2220 ...
# Fetching data offset 2230 ...
# Fetching data offset 2240 ...
# Fetching data offset 2250 ...
# Fetching data offset 2260 ...
# Fetching data offset 2270 ...
# Fetching data offset 2280 ...
# Fetching data offset 2290 ...
# Fetching data offset 2300 ...
# Fetching data offset 2310 ...
# Fetching data offset 2320 ...
# Fetching data offset 2330 ...
# Fetching data offset 2340 ...
# Fetching data offset 2350 ...
# Fetching data offset 2360 ...
# Fetching data offset 2370 ...
# Fetching data offset 2380 ...
# Fetching data offset 2390 ...
# Fetching data offset 2400 ...
# Fetching data offset 2410 ...
# Fetching data offset 2420 ...
# Fetching data offset 2430 ...
# Fetching data offset 2440 ...
# Fetching data offset 2450 ...
# Fetching data offset 2460 ...
# Fetching data offset 2470 ...
# Fetching data offset 2480 ...
# Fetching data offset 2490 ...
# Fetching data offset 2500 ...
# Fetching data offset 2510 ...
# Fetching data offset 2520 ...
# Fetching data offset 2530 ...
# Fetching data offset 2540 ...
# Fetching data offset 2550 ...
# Fetching data offset 2560 ...
# Fetching data offset 2570 ...
# Fetching data offset 2580 ...
# Fetching data offset 2590 ...
# Fetching data offset 2600 ...
# Fetching data offset 2610 ...
# Fetching data offset 2620 ...
# Fetching data offset 2630 ...
# Fetching data offset 2640 ...
# Fetching data offset 2650 ...
# Fetching data offset 2660 ...
# Fetching data offset 2670 ...
# Fetching data offset 2680 ...
# Fetching data offset 2690 ...
# Fetching data offset 2700 ...
# Fetching data offset 2710 ...
# Fetching data offset 2720 ...
# Fetching data offset 2730 ...
# Fetching data offset 2740 ...
# Fetching data offset 2750 ...
# Fetching data offset 2760 ...
# Fetching data offset 2770 ...
# Fetching data offset 2780 ...
# Fetching data offset 2790 ...
# Fetching data offset 2800 ...
# Fetching data offset 2810 ...
# Fetching data offset 2820 ...
# Fetching data offset 2830 ...
# Fetching data offset 2840 ...
# Fetching data offset 2850 ...
# Fetching data offset 2860 ...
# Fetching data offset 2870 ...
# Fetching data offset 2880 ...
# Fetching data offset 2890 ...
# Fetching data offset 2900 ...
# Fetching data offset 2910 ...
# Fetching data offset 2920 ...
# Fetching data offset 2930 ...
# Fetching data offset 2940 ...
# Fetching data offset 2950 ...
# Fetching data offset 2960 ...
# Fetching data offset 2970 ...
# Fetching data offset 2980 ...
# Fetching data offset 2990 ...
# Fetching data offset 3000 ...
# Fetching data offset 3010 ...
# Fetching data offset 3020 ...
# Fetching data offset 3030 ...
# Fetching data offset 3040 ...
# Fetching data offset 3050 ...
# Fetching data offset 3060 ...
# Fetching data offset 3070 ...
# Fetching data offset 3080 ...
# Fetching data offset 3090 ...
# Fetching data offset 3100 ...
# Fetching data offset 3110 ...
# Fetching data offset 3120 ...
# Fetching data offset 3130 ...
# Fetching data offset 3140 ...
# Fetching data offset 3150 ...
# Fetching data offset 3160 ...
# Fetching data offset 3170 ...
# Fetching data offset 3180 ...
# Fetching data offset 3190 ...
# Fetching data offset 3200 ...
# Fetching data offset 3210 ...
# Fetching data offset 3220 ...
# Fetching data offset 3230 ...
# Fetching data offset 3240 ...
# Fetching data offset 3250 ...
# Fetching data offset 3260 ...
# Fetching data offset 3270 ...
# Fetching data offset 3280 ...
# Fetching data offset 3290 ...
# Fetching data offset 3300 ...
# Fetching data offset 3310 ...
# Fetching data offset 3320 ...
# Fetching data offset 3330 ...
# Fetching data offset 3340 ...
# Fetching data offset 3350 ...
# Fetching data offset 3360 ...
# Fetching data offset 3370 ...
# Fetching data offset 3380 ...
# Fetching data offset 3390 ...
# Fetching data offset 3400 ...
# Fetching data offset 3410 ...
# Fetching data offset 3420 ...
# Fetching data offset 3430 ...
# Fetching data offset 3440 ...
# Fetching data offset 3450 ...
# Fetching data offset 3460 ...
# Fetching data offset 3470 ...
# Fetching data offset 3480 ...
# Fetching data offset 3490 ...
# Fetching data offset 3500 ...
# Fetching data offset 3510 ...
# Fetching data offset 3520 ...
# Fetching data offset 3530 ...
# Fetching data offset 3540 ...
# Fetching data offset 3550 ...
# Fetching data offset 3560 ...
# Fetching data offset 3570 ...
# Fetching data offset 3580 ...
# Fetching data offset 3590 ...
# Fetching data offset 3600 ...
# Fetching data offset 3610 ...
# Fetching data offset 3620 ...
# Fetching data offset 3630 ...
# Fetching data offset 3640 ...
# Fetching data offset 3650 ...
# Fetching data offset 3660 ...
# Fetching data offset 3670 ...
# Fetching data offset 3680 ...
# Fetching data offset 3690 ...
# Fetching data offset 3700 ...
# Fetching data offset 3710 ...
# Fetching data offset 3720 ...
# Fetching data offset 3730 ...
# Fetching data offset 3740 ...
# Fetching data offset 3750 ...
# Fetching data offset 3760 ...
# Fetching data offset 3770 ...
# Fetching data offset 3780 ...
# Fetching data offset 3790 ...
# Fetching data offset 3800 ...
# Fetching data offset 3810 ...
# Fetching data offset 3820 ...
# Fetching data offset 3830 ...
# Fetching data offset 3840 ...
# Fetching data offset 3850 ...
# Fetching data offset 3860 ...
# Fetching data offset 3870 ...
# Fetching data offset 3880 ...
# Fetching data offset 3890 ...
# Fetching data offset 3900 ...
# Fetching data offset 3910 ...
# Fetching data offset 3920 ...
# Fetching data offset 3930 ...
# Fetching data offset 3940 ...
# Fetching data offset 3950 ...
# Fetching data offset 3960 ...
# Fetching data offset 3970 ...
# Fetching data offset 3980 ...
# Fetching data offset 3990 ...
# Fetching data offset 4000 ...
# Fetching data offset 4010 ...
# Fetching data offset 4020 ...
# Fetching data offset 4030 ...
# Fetching data offset 4040 ...
# Fetching data offset 4050 ...
# Fetching data offset 4060 ...
# Fetching data offset 4070 ...
# Fetching data offset 4080 ...
# Fetching data offset 4090 ...
# Fetching data offset 4100 ...
# Fetching data offset 4110 ...
# Fetching data offset 4120 ...
# Fetching data offset 4130 ...
# Fetching data offset 4140 ...
# Fetching data offset 4150 ...
# Fetching data offset 4160 ...
# Fetching data offset 4170 ...
# Fetching data offset 4180 ...
# Fetching data offset 4190 ...
# Fetching data offset 4200 ...
# Fetching data offset 4210 ...
# Fetching data offset 4220 ...
# Fetching data offset 4230 ...
# Fetching data offset 4240 ...
# Fetching data offset 4250 ...
# Fetching data offset 4260 ...
# Fetching data offset 4270 ...
# Fetching data offset 4280 ...
# Fetching data offset 4290 ...
# Fetching data offset 4300 ...
# Fetching data offset 4310 ...
# Fetching data offset 4320 ...
# Fetching data offset 4330 ...
# Fetching data offset 4340 ...
# Fetching data offset 4350 ...
# Fetching data offset 4360 ...
# Fetching data offset 4370 ...
# Fetching data offset 4380 ...
# Fetching data offset 4390 ...
# Fetching data offset 4400 ...
# Fetching data offset 4410 ...
# Fetching data offset 4420 ...
# Fetching data offset 4430 ...
# Fetching data offset 4440 ...
# Fetching data offset 4450 ...
# Fetching data offset 4460 ...
# Fetching data offset 4470 ...
# Fetching data offset 4480 ...
# Fetching data offset 4490 ...
# Fetching data offset 4500 ...
# Fetching data offset 4510 ...
# Fetching data offset 4520 ...
# Fetching data offset 4530 ...
# Fetching data offset 4540 ...
# Fetching data offset 4550 ...
# Fetching data offset 4560 ...
# Fetching data offset 4570 ...
# Fetching data offset 4580 ...
# Fetching data offset 4590 ...
# Fetching data offset 4600 ...
# Fetching data offset 4610 ...
# Fetching data offset 4620 ...
# Fetching data offset 4630 ...
# Fetching data offset 4640 ...
# Fetching data offset 4650 ...
# Fetching data offset 4660 ...
# Fetching data offset 4670 ...
# Fetching data offset 4680 ...
# Fetching data offset 4690 ...
# Fetching data offset 4700 ...
# Fetching data offset 4710 ...
# Fetching data offset 4720 ...
# Fetching data offset 4730 ...
# Fetching data offset 4740 ...
# Fetching data offset 4750 ...
# Fetching data offset 4760 ...
# Fetching data offset 4770 ...
# Fetching data offset 4780 ...
# Fetching data offset 4790 ...
# Fetching data offset 4800 ...
# Fetching data offset 4810 ...
# Fetching data offset 4820 ...
# Fetching data offset 4830 ...
# Fetching data offset 4840 ...
# Fetching data offset 4850 ...
# Fetching data offset 4860 ...
# Fetching data offset 4870 ...
# Fetching data offset 4880 ...
# Fetching data offset 4890 ...
# Fetching data offset 4900 ...
# Fetching data offset 4910 ...
# Fetching data offset 4920 ...
# Fetching data offset 4930 ...
# Fetching data offset 4940 ...
# Fetching data offset 4950 ...
# Fetching data offset 4960 ...
# Fetching data offset 4970 ...
# Fetching data offset 4980 ...
# Fetching data offset 4990 ...
# Fetching data offset 5000 ...
# Fetching data offset 5010 ...
# Fetching data offset 5020 ...
# Fetching data offset 5030 ...
# Fetching data offset 5040 ...
# Fetching data offset 5050 ...
# Fetching data offset 5060 ...
# Fetching data offset 5070 ...
# Fetching data offset 5080 ...
# Fetching data offset 5090 ...
# Fetching data offset 5100 ...
# Fetching data offset 5110 ...
# Fetching data offset 5120 ...
# Fetching data offset 5130 ...
# Fetching data offset 5140 ...
# Fetching data offset 5150 ...
# Fetching data offset 5160 ...
# Fetching data offset 5170 ...
# Fetching data offset 5180 ...
# Fetching data offset 5190 ...
# Fetching data offset 5200 ...
# Fetching data offset 5210 ...
# Fetching data offset 5220 ...
# Fetching data offset 5230 ...
# Fetching data offset 5240 ...
# Fetching data offset 5250 ...
# Fetching data offset 5260 ...
# Fetching data offset 5270 ...
# Fetching data offset 5280 ...
# Fetching data offset 5290 ...
# Fetching data offset 5300 ...
# Fetching data offset 5310 ...
# Fetching data offset 5320 ...
# Fetching data offset 5330 ...
# Fetching data offset 5340 ...
# Fetching data offset 5350 ...
# Fetching data offset 5360 ...
# Fetching data offset 5370 ...
# Fetching data offset 5380 ...
# Fetching data offset 5390 ...
# Fetching data offset 5400 ...
# Fetching data offset 5410 ...
# Fetching data offset 5420 ...
# Fetching data offset 5430 ...
# Fetching data offset 5440 ...
# Fetching data offset 5450 ...
# Fetching data offset 5460 ...
# Fetching data offset 5470 ...
# Fetching data offset 5480 ...
# Fetching data offset 5490 ...
# Fetching data offset 5500 ...
# Fetching data offset 5510 ...
# Fetching data offset 5520 ...
# Fetching data offset 5530 ...
# Fetching data offset 5540 ...
# Fetching data offset 5550 ...
# Fetching data offset 5560 ...
# Fetching data offset 5570 ...
# Fetching data offset 5580 ...
# Fetching data offset 5590 ...
# Fetching data offset 5600 ...
# Fetching data offset 5610 ...
# Fetching data offset 5620 ...
# Fetching data offset 5630 ...
# Fetching data offset 5640 ...
# Fetching data offset 5650 ...
# Fetching data offset 5660 ...
# Fetching data offset 5670 ...
# Fetching data offset 5680 ...
# Fetching data offset 5690 ...
# Fetching data offset 5700 ...
# Fetching data offset 5710 ...
# Fetching data offset 5720 ...
# Fetching data offset 5730 ...
# Fetching data offset 5740 ...
# Fetching data offset 5750 ...
# Fetching data offset 5760 ...
# Fetching data offset 5770 ...
# Fetching data offset 5780 ...
# Fetching data offset 5790 ...
# Fetching data offset 5800 ...
# Fetching data offset 5810 ...
# Fetching data offset 5820 ...
# Fetching data offset 5830 ...
# Fetching data offset 5840 ...
# Fetching data offset 5850 ...
# Fetching data offset 5860 ...
# Fetching data offset 5870 ...
# Fetching data offset 5880 ...
# Fetching data offset 5890 ...
# Fetching data offset 5900 ...
# Fetching data offset 5910 ...
# Fetching data offset 5920 ...
# Fetching data offset 5930 ...
# Fetching data offset 5940 ...
# Fetching data offset 5950 ...
# Fetching data offset 5960 ...
# Fetching data offset 5970 ...
# Fetching data offset 5980 ...
# Fetching data offset 5990 ...
# Fetching data offset 6000 ...
# Fetching data offset 6010 ...
# Fetching data offset 6020 ...
# Fetching data offset 6030 ...
# Fetching data offset 6040 ...
# Fetching data offset 6050 ...
# Fetching data offset 6060 ...
# Fetching data offset 6070 ...
# Fetching data offset 6080 ...
# Fetching data offset 6090 ...
# Fetching data offset 6100 ...
# Fetching data offset 6110 ...
# Fetching data offset 6120 ...
# Fetching data offset 6130 ...
# Fetching data offset 6140 ...
# Fetching data offset 6150 ...
# Fetching data offset 6160 ...
# Fetching data offset 6170 ...
# Fetching data offset 6180 ...
# Fetching data offset 6190 ...
# Fetching data offset 6200 ...
# Fetching data offset 6210 ...
# Fetching data offset 6220 ...
# Fetching data offset 6230 ...
# Fetching data offset 6240 ...
# Fetching data offset 6250 ...
# Fetching data offset 6260 ...
# Fetching data offset 6270 ...
# Fetching data offset 6280 ...
# Fetching data offset 6290 ...
# Fetching data offset 6300 ...
# Fetching data offset 6310 ...
# Fetching data offset 6320 ...
# Fetching data offset 6330 ...
# Fetching data offset 6340 ...
# Fetching data offset 6350 ...
# Fetching data offset 6360 ...
# Fetching data offset 6370 ...
# Fetching data offset 6380 ...
# Fetching data offset 6390 ...
# Fetching data offset 6400 ...
# Fetching data offset 6410 ...
# Fetching data offset 6420 ...
# Fetching data offset 6430 ...
# Fetching data offset 6440 ...
# Fetching data offset 6450 ...
# Fetching data offset 6460 ...
# Fetching data offset 6470 ...
# Fetching data offset 6480 ...
# Fetching data offset 6490 ...
# Fetching data offset 6500 ...
# Fetching data offset 6510 ...
# Fetching data offset 6520 ...
# Fetching data offset 6530 ...
# Fetching data offset 6540 ...
# Fetching data offset 6550 ...
# Fetching data offset 6560 ...
# Fetching data offset 6570 ...
# Fetching data offset 6580 ...
# Fetching data offset 6590 ...
# Fetching data offset 6600 ...
# Fetching data offset 6610 ...
# Fetching data offset 6620 ...
# Fetching data offset 6630 ...
# Fetching data offset 6640 ...
# Fetching data offset 6650 ...
# Fetching data offset 6660 ...
# Fetching data offset 6670 ...
# Fetching data offset 6680 ...
# Fetching data offset 6690 ...
# Fetching data offset 6700 ...
# Fetching data offset 6710 ...
# Fetching data offset 6720 ...
# Fetching data offset 6730 ...
# Fetching data offset 6740 ...
# Fetching data offset 6750 ...
# Fetching data offset 6760 ...
# Fetching data offset 6770 ...
# Fetching data offset 6780 ...
# Fetching data offset 6790 ...
# Fetching data offset 6800 ...
# Fetching data offset 6810 ...
# Fetching data offset 6820 ...
# Fetching data offset 6830 ...
# Fetching data offset 6840 ...
# Fetching data offset 6850 ...
# Fetching data offset 6860 ...
# Fetching data offset 6870 ...
# Fetching data offset 6880 ...
# Fetching data offset 6890 ...
# Fetching data offset 6900 ...
# Fetching data offset 6910 ...
# Fetching data offset 6920 ...
# Fetching data offset 6930 ...
# Fetching data offset 6940 ...
# Fetching data offset 6950 ...
# Fetching data offset 6960 ...
# Fetching data offset 6970 ...
# Fetching data offset 6980 ...
# Fetching data offset 6990 ...
# Fetching data offset 7000 ...
# Fetching data offset 7010 ...
# Fetching data offset 7020 ...
# Fetching data offset 7030 ...
# Fetching data offset 7040 ...
# Fetching data offset 7050 ...
# Fetching data offset 7060 ...
# Fetching data offset 7070 ...
# Fetching data offset 7080 ...
# Fetching data offset 7090 ...
# Fetching data offset 7100 ...
# Fetching data offset 7110 ...
# Fetching data offset 7120 ...
# Fetching data offset 7130 ...
# Fetching data offset 7140 ...
# Fetching data offset 7150 ...
# Fetching data offset 7160 ...
# Fetching data offset 7170 ...
# Fetching data offset 7180 ...
# Fetching data offset 7190 ...
# Fetching data offset 7200 ...
# Fetching data offset 7210 ...
# Fetching data offset 7220 ...
# Fetching data offset 7230 ...
# Fetching data offset 7240 ...
# Fetching data offset 7250 ...
# Fetching data offset 7260 ...
# Fetching data offset 7270 ...
# Fetching data offset 7280 ...
# Fetching data offset 7290 ...
# Fetching data offset 7300 ...
# Fetching data offset 7310 ...
# Fetching data offset 7320 ...
# Fetching data offset 7330 ...
# Fetching data offset 7340 ...
# Fetching data offset 7350 ...
# Fetching data offset 7360 ...
# Fetching data offset 7370 ...
# Fetching data offset 7380 ...
# Fetching data offset 7390 ...
# Fetching data offset 7400 ...
# Fetching data offset 7410 ...
# Fetching data offset 7420 ...
# Fetching data offset 7430 ...
# Fetching data offset 7440 ...
# Fetching data offset 7450 ...
# Fetching data offset 7460 ...
# Fetching data offset 7470 ...
# Fetching data offset 7480 ...
# Fetching data offset 7490 ...
# Fetching data offset 7500 ...
# Fetching data offset 7510 ...
# Fetching data offset 7520 ...
# Fetching data offset 7530 ...
# Fetching data offset 7540 ...
# Fetching data offset 7550 ...
# Fetching data offset 7560 ...
# Fetching data offset 7570 ...
# Fetching data offset 7580 ...
# Fetching data offset 7590 ...
# Fetching data offset 7600 ...
# Fetching data offset 7610 ...
# Fetching data offset 7620 ...
# Fetching data offset 7630 ...
# Fetching data offset 7640 ...
# Fetching data offset 7650 ...
# Fetching data offset 7660 ...
# Fetching data offset 7670 ...
# Fetching data offset 7680 ...
# Fetching data offset 7690 ...
# Fetching data offset 7700 ...
# Fetching data offset 7710 ...
# Fetching data offset 7720 ...
# Fetching data offset 7730 ...
# Fetching data offset 7740 ...
# Fetching data offset 7750 ...
# Fetching data offset 7760 ...
# Fetching data offset 7770 ...
# Fetching data offset 7780 ...
# Fetching data offset 7790 ...
# Fetching data offset 7800 ...
# Fetching data offset 7810 ...
# Fetching data offset 7820 ...
# Fetching data offset 7830 ...
# Fetching data offset 7840 ...
# Fetching data offset 7850 ...
# Fetching data offset 7860 ...
# Fetching data offset 7870 ...
# Fetching data offset 7880 ...
# Fetching data offset 7890 ...
# Fetching data offset 7900 ...
# Fetching data offset 7910 ...
# Fetching data offset 7920 ...
# Fetching data offset 7930 ...
# Fetching data offset 7940 ...
# Fetching data offset 7950 ...
# Fetching data offset 7960 ...
# Fetching data offset 7970 ...
# Fetching data offset 7980 ...
# Fetching data offset 7990 ...
# Fetching data offset 8000 ...
# Fetching data offset 8010 ...
# Fetching data offset 8020 ...
# Fetching data offset 8030 ...
# Fetching data offset 8040 ...
# Fetching data offset 8050 ...
# Fetching data offset 8060 ...
# Fetching data offset 8070 ...
# Fetching data offset 8080 ...
# Fetching data offset 8090 ...
# Fetching data offset 8100 ...
# Fetching data offset 8110 ...
# Fetching data offset 8120 ...
# Fetching data offset 8130 ...
# Fetching data offset 8140 ...
# Fetching data offset 8150 ...
# Fetching data offset 8160 ...
# Fetching data offset 8170 ...
# Fetching data offset 8180 ...
# Fetching data offset 8190 ...
# Fetching data offset 8200 ...
# Fetching data offset 8210 ...
# Fetching data offset 8220 ...
# Fetching data offset 8230 ...
# Fetching data offset 8240 ...
# Fetching data offset 8250 ...
# Fetching data offset 8260 ...
# Fetching data offset 8270 ...
# Fetching data offset 8280 ...
# Fetching data offset 8290 ...
# Fetching data offset 8300 ...
# Fetching data offset 8310 ...
# Fetching data offset 8320 ...
# Fetching data offset 8330 ...
# Fetching data offset 8340 ...
# Fetching data offset 8350 ...
# Fetching data offset 8360 ...
# Fetching data offset 8370 ...
# Fetching data offset 8380 ...
# Fetching data offset 8390 ...
# Fetching data offset 8400 ...
# Fetching data offset 8410 ...
# Fetching data offset 8420 ...
# Fetching data offset 8430 ...
# Fetching data offset 8440 ...
# Fetching data offset 8450 ...
# Fetching data offset 8460 ...
# Fetching data offset 8470 ...
# Fetching data offset 8480 ...
# Fetching data offset 8490 ...
# Fetching data offset 8500 ...
# Fetching data offset 8510 ...
# Fetching data offset 8520 ...
# Fetching data offset 8530 ...
# Fetching data offset 8540 ...
# Fetching data offset 8550 ...
# Fetching data offset 8560 ...
# Fetching data offset 8570 ...
# Fetching data offset 8580 ...
# Fetching data offset 8590 ...
# Fetching data offset 8600 ...
# Fetching data offset 8610 ...
# Fetching data offset 8620 ...
# Fetching data offset 8630 ...
# Fetching data offset 8640 ...
# Fetching data offset 8650 ...
# Fetching data offset 8660 ...
# Fetching data offset 8670 ...
# Fetching data offset 8680 ...
# Fetching data offset 8690 ...
# Fetching data offset 8700 ...
# Fetching data offset 8710 ...
# Fetching data offset 8720 ...
# Fetching data offset 8730 ...
# Fetching data offset 8740 ...
# Fetching data offset 8750 ...
# Fetching data offset 8760 ...
# Fetching data offset 8770 ...
# Fetching data offset 8780 ...
# Fetching data offset 8790 ...
# Fetching data offset 8800 ...
# Fetching data offset 8810 ...
# Fetching data offset 8820 ...
# Fetching data offset 8830 ...
# Fetching data offset 8840 ...
# Fetching data offset 8850 ...
# Fetching data offset 8860 ...
# Fetching data offset 8870 ...
# Fetching data offset 8880 ...
# Fetching data offset 8890 ...
# Fetching data offset 8900 ...
# Fetching data offset 8910 ...
# Fetching data offset 8920 ...
# Fetching data offset 8930 ...
# Fetching data offset 8940 ...
# Fetching data offset 8950 ...
# Fetching data offset 8960 ...
# Fetching data offset 8970 ...
# Fetching data offset 8980 ...
# Fetching data offset 8990 ...
# Fetching data offset 9000 ...
# Fetching data offset 9010 ...
# Fetching data offset 9020 ...
# Fetching data offset 9030 ...
# Fetching data offset 9040 ...
# Fetching data offset 9050 ...
# Fetching data offset 9060 ...
# Fetching data offset 9070 ...
# Fetching data offset 9080 ...
# Fetching data offset 9090 ...
# Fetching data offset 9100 ...
# Fetching data offset 9110 ...
# Fetching data offset 9120 ...
# Fetching data offset 9130 ...
# Fetching data offset 9140 ...
# Fetching data offset 9150 ...
# Fetching data offset 9160 ...
# Fetching data offset 9170 ...
# Fetching data offset 9180 ...
# Fetching data offset 9190 ...
# Fetching data offset 9200 ...
# Fetching data offset 9210 ...
# Fetching data offset 9220 ...
# Fetching data offset 9230 ...
# Fetching data offset 9240 ...
# Fetching data offset 9250 ...
# Fetching data offset 9260 ...
# Fetching data offset 9270 ...
# Fetching data offset 9280 ...
# Fetching data offset 9290 ...
# Fetching data offset 9300 ...
# Fetching data offset 9310 ...
# Fetching data offset 9320 ...
# Fetching data offset 9330 ...
# Fetching data offset 9340 ...
# Fetching data offset 9350 ...
# Fetching data offset 9360 ...
# Fetching data offset 9370 ...
# Fetching data offset 9380 ...
# Fetching data offset 9390 ...
# Fetching data offset 9400 ...
# Fetching data offset 9410 ...
# Fetching data offset 9420 ...
# Fetching data offset 9430 ...
# Fetching data offset 9440 ...
# Fetching data offset 9450 ...
# Fetching data offset 9460 ...
# Fetching data offset 9470 ...
# Fetching data offset 9480 ...
# Fetching data offset 9490 ...
# Fetching data offset 9500 ...
# Fetching data offset 9510 ...
# Fetching data offset 9520 ...
# Fetching data offset 9530 ...
# Fetching data offset 9540 ...
#
# ✅ Selesai! Total data terkumpul: 9541

# %%
import pandas as pd

# Buat DataFrame
df = pd.DataFrame(all_data, columns=["Instansi", "Jenis_Pengadaan", "Jenis_Formasi", "Jabatan", "Lokasi_Unit_Kerja", "Jumlah_Formasi", "Gaji_MIN", "Gaji_MAX","jumlah_Lulus_Verif"])
df
# Out:
#                                Instansi Jenis_Pengadaan  \
# 0     Arsip Nasional Republik Indonesia            CPNS
# 1     Arsip Nasional Republik Indonesia            CPNS
# 2     Arsip Nasional Republik Indonesia            CPNS
# 3     Arsip Nasional Republik Indonesia            CPNS
# 4     Arsip Nasional Republik Indonesia            CPNS
# ...                                 ...             ...
# 9536       Setjen Komisi Pemilihan Umum            CPNS
# 9537       Setjen Komisi Pemilihan Umum            CPNS
# 9538       Setjen Komisi Pemilihan Umum            CPNS
# 9539                   Setjen WANTANNAS            CPNS
# 9540                   Setjen WANTANNAS            CPNS
#
#                Jenis_Formasi  \
# 0                       UMUM
# 1     PUTRA/PUTRI KALIMANTAN
# 2     PUTRA/PUTRI KALIMANTAN
# 3                       UMUM
# 4                       UMUM
# ...                      ...
# 9536                    UMUM
# 9537         LULUSAN TERBAIK
# 9538  PUTRA/PUTRI KALIMANTAN
# 9539  PUTRA/PUTRI KALIMANTAN
# 9540                    UMUM
#
#                                                Jabatan  \
# 0     ANALIS SUMBER DAYA MANUSIA APARATUR AHLI PERTAMA
# 1                               ARSIPARIS AHLI PERTAMA
# 2                               ARSIPARIS AHLI PERTAMA
# 3                               ARSIPARIS AHLI PERTAMA
# 4                               ARSIPARIS AHLI PERTAMA
# ...                                                ...
# 9536                     PRANATA KOMPUTER AHLI PERTAMA
# 9537                     PRANATA KOMPUTER AHLI PERTAMA
# 9538                     PRANATA KOMPUTER AHLI PERTAMA
# 9539                             SANDIMAN AHLI PERTAMA
# 9540                             SANDIMAN AHLI PERTAMA
#
#                                       Lokasi_Unit_Kerja  Jumlah_Formasi  \
# 0     ARSIP NASIONAL REPUBLIK INDONESIA | SEKRETARIA...               2
# 1     ARSIP NASIONAL REPUBLIK INDONESIA | DEPUTI BID...               1
# 2     ARSIP NASIONAL REPUBLIK INDONESIA | DEPUTI BID...               1
# 3     ARSIP NASIONAL REPUBLIK INDONESIA | DEPUTI BID...               2
# 4     ARSIP NASIONAL REPUBLIK INDONESIA | DEPUTI BID...               2
# ...                                                 ...             ...
# 9536                           SEKRETARIAT JENDERAL KPU              37
# 9537                           SEKRETARIAT JENDERAL KPU               2
# 9538                           SEKRETARIAT JENDERAL KPU               1
# 9539  SEKRETARIAT JENDERAL DEWAN KETAHANAN NASIONAL ...               1
# 9540  SEKRETARIAT JENDERAL DEWAN KETAHANAN NASIONAL ...               2
#
#      Gaji_MIN Gaji_MAX  jumlah_Lulus_Verif
# 0     7994000  8601000                  37
# 1     7974000  8581000                   3
# 2     7974000  8581000                   9
# 3     7974000  8581000                  37
# 4     7974000  8581000                  28
# ...       ...      ...                 ...
# 9536  6000000  7500000                 428
# 9537  6000000  7500000                   4
# 9538  6000000  7500000                   2
# 9539  7457120  8064378                   1
# 9540  7457120  8064378                  13
#
# [9541 rows x 9 columns]
